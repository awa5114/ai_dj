# %%
import youtube_dl
from spleeter.separator import Separator
import os
# Out:
# ERROR:root:Internal Python error in the inspect module.
# Below is the traceback from this internal error.
#
# Traceback (most recent call last):
#   File "/home/awa5114/.pyenv/versions/lewagon/lib/python3.8/site-packages/IPython/core/interactiveshell.py", line 3437, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "<ipython-input-1-db188c7b8e4a>", line 2, in <module>
#     from spleeter.separator import Separator
#   File "/home/awa5114/.pyenv/versions/lewagon/lib/python3.8/site-packages/spleeter/separator.py", line 26, in <module>
#     import tensorflow as tf
#   File "/home/awa5114/.pyenv/versions/lewagon/lib/python3.8/site-packages/tensorflow/__init__.py", line 41, in <module>
#     from tensorflow.python.tools import module_util as _module_util
#   File "/home/awa5114/.pyenv/versions/lewagon/lib/python3.8/site-packages/tensorflow/python/__init__.py", line 47, in <module>
#     from tensorflow.python import keras
#   File "/home/awa5114/.pyenv/versions/lewagon/lib/python3.8/site-packages/tensorflow/python/keras/__init__.py", line 27, in <module>
#     from tensorflow.python.keras import models
#   File "/home/awa5114/.pyenv/versions/lewagon/lib/python3.8/site-packages/tensorflow/python/keras/models.py", line 26, in <module>
#     from tensorflow.python.keras.engine import functional
#   File "/home/awa5114/.pyenv/versions/lewagon/lib/python3.8/site-packages/tensorflow/python/keras/engine/functional.py", line 35, in <module>
#     from tensorflow.python.keras.engine import input_layer as input_layer_module
#   File "/home/awa5114/.pyenv/versions/lewagon/lib/python3.8/site-packages/tensorflow/python/keras/engine/input_layer.py", line 27, in <module>
#     from tensorflow.python.keras.distribute import distributed_training_utils
#   File "/home/awa5114/.pyenv/versions/lewagon/lib/python3.8/site-packages/tensorflow/python/keras/distribute/distributed_training_utils.py", line 38, in <module>
#     from tensorflow.python.keras import callbacks
#   File "/home/awa5114/.pyenv/versions/lewagon/lib/python3.8/site-packages/tensorflow/python/keras/callbacks.py", line 66, in <module>
#     import requests
#   File "/home/awa5114/.pyenv/versions/lewagon/lib/python3.8/site-packages/requests/__init__.py", line 44, in <module>
#     import chardet
#   File "/home/awa5114/.pyenv/versions/lewagon/lib/python3.8/site-packages/chardet/__init__.py", line 20, in <module>
#     from .universaldetector import UniversalDetector
#   File "/home/awa5114/.pyenv/versions/lewagon/lib/python3.8/site-packages/chardet/universaldetector.py", line 48, in <module>
#     from .sbcsgroupprober import SBCSGroupProber
#   File "/home/awa5114/.pyenv/versions/lewagon/lib/python3.8/site-packages/chardet/sbcsgroupprober.py", line 31, in <module>
#     from .langcyrillicmodel import (Win1251CyrillicModel, Koi8rModel,
#   File "<frozen importlib._bootstrap>", line 991, in _find_and_load
#   File "<frozen importlib._bootstrap>", line 975, in _find_and_load_unlocked
#   File "<frozen importlib._bootstrap>", line 671, in _load_unlocked
#   File "<frozen importlib._bootstrap_external>", line 779, in exec_module
#   File "<frozen importlib._bootstrap_external>", line 874, in get_code
#   File "<frozen importlib._bootstrap_external>", line 973, in get_data
# KeyboardInterrupt
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/home/awa5114/.pyenv/versions/lewagon/lib/python3.8/site-packages/IPython/core/interactiveshell.py", line 2061, in showtraceback
#     stb = value._render_traceback_()
# AttributeError: 'KeyboardInterrupt' object has no attribute '_render_traceback_'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/home/awa5114/.pyenv/versions/lewagon/lib/python3.8/site-packages/IPython/core/ultratb.py", line 1101, in get_records
#     return _fixed_getinnerframes(etb, number_of_lines_of_context, tb_offset)
#   File "/home/awa5114/.pyenv/versions/lewagon/lib/python3.8/site-packages/IPython/core/ultratb.py", line 248, in wrapped
#     return f(*args, **kwargs)
#   File "/home/awa5114/.pyenv/versions/lewagon/lib/python3.8/site-packages/IPython/core/ultratb.py", line 281, in _fixed_getinnerframes
#     records = fix_frame_records_filenames(inspect.getinnerframes(etb, context))
#   File "/home/awa5114/.pyenv/versions/3.8.6/lib/python3.8/inspect.py", line 1503, in getinnerframes
#     frameinfo = (tb.tb_frame,) + getframeinfo(tb, context)
#   File "/home/awa5114/.pyenv/versions/3.8.6/lib/python3.8/inspect.py", line 1461, in getframeinfo
#     filename = getsourcefile(frame) or getfile(frame)
#   File "/home/awa5114/.pyenv/versions/3.8.6/lib/python3.8/inspect.py", line 708, in getsourcefile
#     if getattr(getmodule(object, filename), '__loader__', None) is not None:
#   File "/home/awa5114/.pyenv/versions/3.8.6/lib/python3.8/inspect.py", line 754, in getmodule
#     os.path.realpath(f)] = module.__name__
#   File "/home/awa5114/.pyenv/versions/3.8.6/lib/python3.8/posixpath.py", line 392, in realpath
#     return abspath(path)
#   File "/home/awa5114/.pyenv/versions/3.8.6/lib/python3.8/posixpath.py", line 381, in abspath
#     return normpath(path)
#   File "/home/awa5114/.pyenv/versions/3.8.6/lib/python3.8/posixpath.py", line 366, in normpath
#     path = sep.join(comps)
# KeyboardInterrupt
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
#     [... skipping hidden 1 frame]
#
# <ipython-input-1-db188c7b8e4a> in <module>
#       1 import youtube_dl
# ----> 2 from spleeter.separator import Separator
#       3 import os
#
# ~/.pyenv/versions/lewagon/lib/python3.8/site-packages/spleeter/separator.py in <module>
#      25 import numpy as np
# ---> 26 import tensorflow as tf
#      27 from librosa.core import istft, stft
#
# ~/.pyenv/versions/lewagon/lib/python3.8/site-packages/tensorflow/__init__.py in <module>
#      40
# ---> 41 from tensorflow.python.tools import module_util as _module_util
#      42 from tensorflow.python.util.lazy_loader import LazyLoader as _LazyLoader
#
# ~/.pyenv/versions/lewagon/lib/python3.8/site-packages/tensorflow/python/__init__.py in <module>
#      46 from tensorflow.python import distribute
# ---> 47 from tensorflow.python import keras
#      48 from tensorflow.python.feature_column import feature_column_lib as feature_column
#
# ~/.pyenv/versions/lewagon/lib/python3.8/site-packages/tensorflow/python/keras/__init__.py in <module>
#      26 # See b/110718070#comment18 for more details about this import.
# ---> 27 from tensorflow.python.keras import models
#      28
#
# ~/.pyenv/versions/lewagon/lib/python3.8/site-packages/tensorflow/python/keras/models.py in <module>
#      25 from tensorflow.python.keras import optimizers
# ---> 26 from tensorflow.python.keras.engine import functional
#      27 from tensorflow.python.keras.engine import sequential
#
# ~/.pyenv/versions/lewagon/lib/python3.8/site-packages/tensorflow/python/keras/engine/functional.py in <module>
#      34 from tensorflow.python.keras.engine import base_layer_utils
# ---> 35 from tensorflow.python.keras.engine import input_layer as input_layer_module
#      36 from tensorflow.python.keras.engine import keras_tensor
#
# ~/.pyenv/versions/lewagon/lib/python3.8/site-packages/tensorflow/python/keras/engine/input_layer.py in <module>
#      26 from tensorflow.python.keras import backend
# ---> 27 from tensorflow.python.keras.distribute import distributed_training_utils
#      28 from tensorflow.python.keras.engine import base_layer
#
# ~/.pyenv/versions/lewagon/lib/python3.8/site-packages/tensorflow/python/keras/distribute/distributed_training_utils.py in <module>
#      37 from tensorflow.python.keras import backend as K
# ---> 38 from tensorflow.python.keras import callbacks
#      39 from tensorflow.python.keras import metrics as metrics_module
#
# ~/.pyenv/versions/lewagon/lib/python3.8/site-packages/tensorflow/python/keras/callbacks.py in <module>
#      65 try:
# ---> 66   import requests
#      67 except ImportError:
#
# ~/.pyenv/versions/lewagon/lib/python3.8/site-packages/requests/__init__.py in <module>
#      43 import urllib3
# ---> 44 import chardet
#      45 import warnings
#
# ~/.pyenv/versions/lewagon/lib/python3.8/site-packages/chardet/__init__.py in <module>
#      19 from .compat import PY2, PY3
# ---> 20 from .universaldetector import UniversalDetector
#      21 from .version import __version__, VERSION
#
# ~/.pyenv/versions/lewagon/lib/python3.8/site-packages/chardet/universaldetector.py in <module>
#      47 from .mbcsgroupprober import MBCSGroupProber
# ---> 48 from .sbcsgroupprober import SBCSGroupProber
#      49
#
# ~/.pyenv/versions/lewagon/lib/python3.8/site-packages/chardet/sbcsgroupprober.py in <module>
#      30 from .sbcharsetprober import SingleByteCharSetProber
# ---> 31 from .langcyrillicmodel import (Win1251CyrillicModel, Koi8rModel,
#      32                                 Latin5CyrillicModel, MacCyrillicModel,
#
# ~/.pyenv/versions/3.8.6/lib/python3.8/importlib/_bootstrap.py in _find_and_load(name, import_)
#
# ~/.pyenv/versions/3.8.6/lib/python3.8/importlib/_bootstrap.py in _find_and_load_unlocked(name, import_)
#
# ~/.pyenv/versions/3.8.6/lib/python3.8/importlib/_bootstrap.py in _load_unlocked(spec)
#
# ~/.pyenv/versions/3.8.6/lib/python3.8/importlib/_bootstrap_external.py in exec_module(self, module)
#
# ~/.pyenv/versions/3.8.6/lib/python3.8/importlib/_bootstrap_external.py in get_code(self, fullname)
#
# ~/.pyenv/versions/3.8.6/lib/python3.8/importlib/_bootstrap_external.py in get_data(self, path)
#
# KeyboardInterrupt:
#
# During handling of the above exception, another exception occurred:
#
# AttributeError                            Traceback (most recent call last)
# ~/.pyenv/versions/lewagon/lib/python3.8/site-packages/IPython/core/interactiveshell.py in showtraceback(self, exc_tuple, filename, tb_offset, exception_only, running_compiled_code)
#    2060                         # in the engines. This should return a list of strings.
# -> 2061                         stb = value._render_traceback_()
#    2062                     except Exception:
#
# AttributeError: 'KeyboardInterrupt' object has no attribute '_render_traceback_'
#
# During handling of the above exception, another exception occurred:
#
# TypeError                                 Traceback (most recent call last)
#     [... skipping hidden 1 frame]
#
# ~/.pyenv/versions/lewagon/lib/python3.8/site-packages/IPython/core/interactiveshell.py in showtraceback(self, exc_tuple, filename, tb_offset, exception_only, running_compiled_code)
#    2061                         stb = value._render_traceback_()
#    2062                     except Exception:
# -> 2063                         stb = self.InteractiveTB.structured_traceback(etype,
#    2064                                             value, tb, tb_offset=tb_offset)
#    2065
#
# ~/.pyenv/versions/lewagon/lib/python3.8/site-packages/IPython/core/ultratb.py in structured_traceback(self, etype, value, tb, tb_offset, number_of_lines_of_context)
#    1365         else:
#    1366             self.tb = tb
# -> 1367         return FormattedTB.structured_traceback(
#    1368             self, etype, value, tb, tb_offset, number_of_lines_of_context)
#    1369
#
# ~/.pyenv/versions/lewagon/lib/python3.8/site-packages/IPython/core/ultratb.py in structured_traceback(self, etype, value, tb, tb_offset, number_of_lines_of_context)
#    1265         if mode in self.verbose_modes:
#    1266             # Verbose modes need a full traceback
# -> 1267             return VerboseTB.structured_traceback(
#    1268                 self, etype, value, tb, tb_offset, number_of_lines_of_context
#    1269             )
#
# ~/.pyenv/versions/lewagon/lib/python3.8/site-packages/IPython/core/ultratb.py in structured_traceback(self, etype, evalue, etb, tb_offset, number_of_lines_of_context)
#    1122         """Return a nice text document describing the traceback."""
#    1123
# -> 1124         formatted_exception = self.format_exception_as_a_whole(etype, evalue, etb, number_of_lines_of_context,
#    1125                                                                tb_offset)
#    1126
#
# ~/.pyenv/versions/lewagon/lib/python3.8/site-packages/IPython/core/ultratb.py in format_exception_as_a_whole(self, etype, evalue, etb, number_of_lines_of_context, tb_offset)
#    1080
#    1081
# -> 1082         last_unique, recursion_repeat = find_recursion(orig_etype, evalue, records)
#    1083
#    1084         frames = self.format_records(records, last_unique, recursion_repeat)
#
# ~/.pyenv/versions/lewagon/lib/python3.8/site-packages/IPython/core/ultratb.py in find_recursion(etype, value, records)
#     380     # first frame (from in to out) that looks different.
#     381     if not is_recursion_error(etype, value, records):
# --> 382         return len(records), 0
#     383
#     384     # Select filename, lineno, func_name to track frames with
#
# TypeError: object of type 'NoneType' has no len()

# %%
links = [
    "https://www.youtube.com/watch?v=SF8DGbfOFig",
    "https://www.youtube.com/watch?v=Q77vdqA0hnM",
    "https://www.youtube.com/watch?v=1zmxNRc1FXY&ab_channel=MyLifelikeaSoundtrackMyLifelikeaSoundtrack",
    "https://www.youtube.com/watch?v=VIeY1J1M9Ts&ab_channel=VanillaVanilla",
    "https://www.youtube.com/watch?v=L-2CyO8pc0E",
    "https://www.youtube.com/watch?v=xarC5jAiO7w",
    "https://www.youtube.com/watch?v=q5rliCxX8xc",
    "https://www.youtube.com/watch?v=deIhypT_55A",
    "https://www.youtube.com/watch?v=SKUk9RUacDQ",
    "https://www.youtube.com/watch?v=nXOSgekiAJc"
]

# %% [markdown]
# # Download tracks from youtube

# %%
# %time
ydl_args = {
  'format': 'bestaudio/best',
  'outtmpl': 'data/%(title)s.%(ext)s'
}
with youtube_dl.YoutubeDL(ydl_args) as ydl:
    results = ydl.download(links)
# Out:
# CPU times: user 1e+03 ns, sys: 1 µs, total: 2 µs
# Wall time: 3.1 µs
# [youtube] SF8DGbfOFig: Downloading webpage
# [download] data/Total Science & S.P.Y - Piano Funk (Ft. Riya & DāM FunK) [320k].webm has already been downloaded
# [download] 100% of 5.57MiB
# [youtube] Q77vdqA0hnM: Downloading webpage
# [download] data/Two Scoops.webm has already been downloaded
# [download] 100% of 1.96MiB
# [youtube] 1zmxNRc1FXY: Downloading webpage
# [download] data/Oliver feat. Chromeo....Go with it.webm has already been downloaded
# [download] 100% of 3.67MiB
# [youtube] VIeY1J1M9Ts: Downloading webpage
# [download] data/Vanilla - Go.webm has already been downloaded
# [download] 100% of 4.21MiB
# [youtube] L-2CyO8pc0E: Downloading webpage
# [download] data/Steve Monite - Only You.m4a has already been downloaded
# [download] 100% of 6.02MiB
# [ffmpeg] Correcting container in "data/Steve Monite - Only You.m4a"
# [youtube] xarC5jAiO7w: Downloading webpage
# [download] data/ODESZA - A Moment Apart.webm has already been downloaded
# [download] 100% of 3.84MiB
# [youtube] q5rliCxX8xc: Downloading webpage
# [download] data/Bicep - Glue (Original Mix).webm has already been downloaded
# [download] 100% of 4.39MiB
# [youtube] deIhypT_55A: Downloading webpage
# [youtube] deIhypT_55A: Downloading MPD manifest
# [download] data/Shermanology ft ConQuer Jones - OK Cool Aight.webm has already been downloaded
# [download] 100% of 6.94MiB
# [youtube] SKUk9RUacDQ: Downloading webpage
# [download] data/64 Ways (Dam Swindle's 65th Way Dub) feat. Mayer Hawthorne.webm has already been downloaded
# [download] 100% of 7.35MiB
# [youtube] nXOSgekiAJc: Downloading webpage
# [download] data/Disclosure - Expressing What Matters (Visualiser).webm has already been downloaded
# [download] 100% of 4.41MiB

# %% [markdown]
# # Extract filenames

# %%
filepaths = []
with youtube_dl.YoutubeDL(ydl_args) as ydl:
    for link in links:
        filepath = ydl.prepare_filename(ydl.extract_info(link))
        filepaths.append(filepath)
# Out:
# [youtube] SF8DGbfOFig: Downloading webpage
# [download] data/Total Science & S.P.Y - Piano Funk (Ft. Riya & DāM FunK) [320k].webm has already been downloaded
# [download] 100% of 5.57MiB
# [youtube] Q77vdqA0hnM: Downloading webpage
# [download] data/Two Scoops.webm has already been downloaded
# [download] 100% of 1.96MiB
# [youtube] 1zmxNRc1FXY: Downloading webpage
# [download] data/Oliver feat. Chromeo....Go with it.webm has already been downloaded
# [download] 100% of 3.67MiB
# [youtube] VIeY1J1M9Ts: Downloading webpage
# [download] data/Vanilla - Go.webm has already been downloaded
# [download] 100% of 4.21MiB
# [youtube] L-2CyO8pc0E: Downloading webpage
# [download] data/Steve Monite - Only You.m4a has already been downloaded
# [download] 100% of 6.02MiB
# [ffmpeg] Correcting container in "data/Steve Monite - Only You.m4a"
# [youtube] xarC5jAiO7w: Downloading webpage
# [download] data/ODESZA - A Moment Apart.webm has already been downloaded
# [download] 100% of 3.84MiB
# [youtube] q5rliCxX8xc: Downloading webpage
# [download] data/Bicep - Glue (Original Mix).webm has already been downloaded
# [download] 100% of 4.39MiB
# [youtube] deIhypT_55A: Downloading webpage
# [youtube] deIhypT_55A: Downloading MPD manifest
# [download] data/Shermanology ft ConQuer Jones - OK Cool Aight.webm has already been downloaded
# [download] 100% of 6.94MiB
# [youtube] SKUk9RUacDQ: Downloading webpage
# [download] data/64 Ways (Dam Swindle's 65th Way Dub) feat. Mayer Hawthorne.webm has already been downloaded
# [download] 100% of 7.35MiB
# [youtube] nXOSgekiAJc: Downloading webpage
# [download] data/Disclosure - Expressing What Matters (Visualiser).webm has already been downloaded
# [download] 100% of 4.41MiB

# %% [markdown]
# # Apply Spleeter

# %%
separator = Separator('spleeter:5stems')
for filepath in filepaths:
    separator.separate_to_file(filepath, 'data')
# %time
# Out:
# processing/queues.py", line 355, in get
#     with self._rlock:
#   File "/home/awa5114/.pyenv/versions/3.8.6/lib/python3.8/multiprocessing/queues.py", line 355, in get
#     with self._rlock:
#   File "/home/awa5114/.pyenv/versions/3.8.6/lib/python3.8/multiprocessing/queues.py", line 355, in get
#     with self._rlock:
#   File "/home/awa5114/.pyenv/versions/3.8.6/lib/python3.8/multiprocessing/queues.py", line 355, in get
#     with self._rlock:
#   File "/home/awa5114/.pyenv/versions/3.8.6/lib/python3.8/multiprocessing/queues.py", line 355, in get
#     with self._rlock:
#   File "/home/awa5114/.pyenv/versions/3.8.6/lib/python3.8/multiprocessing/pool.py", line 114, in worker
#     task = get()
#   File "/home/awa5114/.pyenv/versions/3.8.6/lib/python3.8/multiprocessing/queues.py", line 355, in get
#     with self._rlock:
#   File "/home/awa5114/.pyenv/versions/3.8.6/lib/python3.8/multiprocessing/queues.py", line 355, in get
#     with self._rlock:
#   File "/home/awa5114/.pyenv/versions/3.8.6/lib/python3.8/multiprocessing/pool.py", line 114, in worker
#     task = get()
#   File "/home/awa5114/.pyenv/versions/3.8.6/lib/python3.8/multiprocessing/pool.py", line 114, in worker
#     task = get()
#   File "/home/awa5114/.pyenv/versions/3.8.6/lib/python3.8/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#   File "/home/awa5114/.pyenv/versions/3.8.6/lib/python3.8/multiprocessing/queues.py", line 355, in get
#     with self._rlock:
#   File "/home/awa5114/.pyenv/versions/3.8.6/lib/python3.8/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#   File "/home/awa5114/.pyenv/versions/3.8.6/lib/python3.8/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#   File "/home/awa5114/.pyenv/versions/3.8.6/lib/python3.8/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#   File "/home/awa5114/.pyenv/versions/3.8.6/lib/python3.8/multiprocessing/pool.py", line 114, in worker
#     task = get()
#   File "/home/awa5114/.pyenv/versions/3.8.6/lib/python3.8/multiprocessing/pool.py", line 114, in worker
#     task = get()
#   File "/home/awa5114/.pyenv/versions/3.8.6/lib/python3.8/multiprocessing/queues.py", line 355, in get
#     with self._rlock:
#   File "/home/awa5114/.pyenv/versions/3.8.6/lib/python3.8/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#   File "/home/awa5114/.pyenv/versions/3.8.6/lib/python3.8/multiprocessing/queues.py", line 355, in get
#     with self._rlock:
#   File "/home/awa5114/.pyenv/versions/3.8.6/lib/python3.8/multiprocessing/queues.py", line 355, in get
#     with self._rlock:
#   File "/home/awa5114/.pyenv/versions/3.8.6/lib/python3.8/multiprocessing/queues.py", line 355, in get
#     with self._rlock:
#   File "/home/awa5114/.pyenv/versions/3.8.6/lib/python3.8/multiprocessing/queues.py", line 355, in get
#     with self._rlock:
#   File "/home/awa5114/.pyenv/versions/3.8.6/lib/python3.8/multiprocessing/queues.py", line 355, in get
#     with self._rlock:
#   File "/home/awa5114/.pyenv/versions/3.8.6/lib/python3.8/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#   File "/home/awa5114/.pyenv/versions/3.8.6/lib/python3.8/multiprocessing/pool.py", line 114, in worker
#     task = get()
# KeyboardInterrupt
#   File "/home/awa5114/.pyenv/versions/3.8.6/lib/python3.8/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#   File "/home/awa5114/.pyenv/versions/3.8.6/lib/python3.8/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#   File "/home/awa5114/.pyenv/versions/3.8.6/lib/python3.8/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#   File "/home/awa5114/.pyenv/versions/3.8.6/lib/python3.8/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#   File "/home/awa5114/.pyenv/versions/3.8.6/lib/python3.8/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#   File "/home/awa5114/.pyenv/versions/3.8.6/lib/python3.8/multiprocessing/queues.py", line 356, in get
#     res = self._reader.recv_bytes()
#   File "/home/awa5114/.pyenv/versions/3.8.6/lib/python3.8/multiprocessing/queues.py", line 355, in get
#     with self._rlock:
#   File "/home/awa5114/.pyenv/versions/3.8.6/lib/python3.8/multiprocessing/queues.py", line 355, in get
#     with self._rlock:
#   File "/home/awa5114/.pyenv/versions/3.8.6/lib/python3.8/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#   File "/home/awa5114/.pyenv/versions/3.8.6/lib/python3.8/multiprocessing/queues.py", line 355, in get
#     with self._rlock:
#   File "/home/awa5114/.pyenv/versions/3.8.6/lib/python3.8/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#   File "/home/awa5114/.pyenv/versions/3.8.6/lib/python3.8/multiprocessing/queues.py", line 355, in get
#     with self._rlock:
#   File "/home/awa5114/.pyenv/versions/3.8.6/lib/python3.8/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#   File "/home/awa5114/.pyenv/versions/3.8.6/lib/python3.8/multiprocessing/queues.py", line 355, in get
#     with self._rlock:
#   File "/home/awa5114/.pyenv/versions/3.8.6/lib/python3.8/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#   File "/home/awa5114/.pyenv/versions/3.8.6/lib/python3.8/multiprocessing/queues.py", line 356, in get
#     res = self._reader.recv_bytes()
#   File "/home/awa5114/.pyenv/versions/3.8.6/lib/python3.8/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#   File "/home/awa5114/.pyenv/versions/3.8.6/lib/python3.8/multiprocessing/queues.py", line 356, in get
#     res = self._reader.recv_bytes()
#   File "/home/awa5114/.pyenv/versions/3.8.6/lib/python3.8/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#   File "/home/awa5114/.pyenv/versions/3.8.6/lib/python3.8/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#   File "/home/awa5114/.pyenv/versions/3.8.6/lib/python3.8/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#   File "/home/awa5114/.pyenv/versions/3.8.6/lib/python3.8/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#   File "/home/awa5114/.pyenv/versions/3.8.6/lib/python3.8/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#   File "/home/awa5114/.pyenv/versions/3.8.6/lib/python3.8/multiprocessing/queues.py", line 355, in get
#     with self._rlock:
#   File "/home/awa5114/.pyenv/versions/3.8.6/lib/python3.8/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#   File "/home/awa5114/.pyenv/versions/3.8.6/lib/python3.8/multiprocessing/queues.py", line 355, in get
#     with self._rlock:
# KeyboardInterrupt
#   File "/home/awa5114/.pyenv/versions/3.8.6/lib/python3.8/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#   File "/home/awa5114/.pyenv/versions/3.8.6/lib/python3.8/multiprocessing/queues.py", line 355, in get
#     with self._rlock:
#   File "/home/awa5114/.pyenv/versions/3.8.6/lib/python3.8/multiprocessing/connection.py", line 216, in recv_bytes
#     buf = self._recv_bytes(maxlength)
#   File "/home/awa5114/.pyenv/versions/3.8.6/lib/python3.8/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#   File "/home/awa5114/.pyenv/versions/3.8.6/lib/python3.8/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#   File "/home/awa5114/.pyenv/versions/3.8.6/lib/python3.8/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#   File "/home/awa5114/.pyenv/versions/3.8.6/lib/python3.8/multiprocessing/connection.py", line 216, in recv_bytes
#     buf = self._recv_bytes(maxlength)
#   File "/home/awa5114/.pyenv/versions/3.8.6/lib/python3.8/multiprocessing/queues.py", line 355, in get
#     with self._rlock:
#   File "/home/awa5114/.pyenv/versions/3.8.6/lib/python3.8/multiprocessing/queues.py", line 355, in get
#     with self._rlock:
#   File "/home/awa5114/.pyenv/versions/3.8.6/lib/python3.8/multiprocessing/queues.py", line 355, in get
#     with self._rlock:
#   File "/home/awa5114/.pyenv/versions/3.8.6/lib/python3.8/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#   File "/home/awa5114/.pyenv/versions/3.8.6/lib/python3.8/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#   File "/home/awa5114/.pyenv/versions/3.8.6/lib/python3.8/multiprocessing/queues.py", line 355, in get
#     with self._rlock:
#   File "/home/awa5114/.pyenv/versions/3.8.6/lib/python3.8/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#   File "/home/awa5114/.pyenv/versions/3.8.6/lib/python3.8/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#   File "/home/awa5114/.pyenv/versions/3.8.6/lib/python3.8/multiprocessing/queues.py", line 355, in get
#     with self._rlock:
#   File "/home/awa5114/.pyenv/versions/3.8.6/lib/python3.8/multiprocessing/queues.py", line 355, in get
#     with self._rlock:
#   File "/home/awa5114/.pyenv/versions/3.8.6/lib/python3.8/multiprocessing/queues.py", line 355, in get
#     with self._rlock:
#   File "/home/awa5114/.pyenv/versions/3.8.6/lib/python3.8/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#   File "/home/awa5114/.pyenv/versions/3.8.6/lib/python3.8/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
# KeyboardInterrupt
#   File "/home/awa5114/.pyenv/versions/3.8.6/lib/python3.8/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#   File "/home/awa5114/.pyenv/versions/3.8.6/lib/python3.8/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#   File "/home/awa5114/.pyenv/versions/3.8.6/lib/python3.8/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#   File "/home/awa5114/.pyenv/versions/3.8.6/lib/python3.8/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#   File "/home/awa5114/.pyenv/versions/3.8.6/lib/python3.8/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#   File "/home/awa5114/.pyenv/versions/3.8.6/lib/python3.8/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#   File "/home/awa5114/.pyenv/versions/3.8.6/lib/python3.8/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#   File "/home/awa5114/.pyenv/versions/3.8.6/lib/python3.8/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#   File "/home/awa5114/.pyenv/versions/3.8.6/lib/python3.8/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#   File "/home/awa5114/.pyenv/versions/3.8.6/lib/python3.8/multiprocessing/queues.py", line 355, in get
#     with self._rlock:
#   File "/home/awa5114/.pyenv/versions/3.8.6/lib/python3.8/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#   File "/home/awa5114/.pyenv/versions/3.8.6/lib/python3.8/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#   File "/home/awa5114/.pyenv/versions/3.8.6/lib/python3.8/multiprocessing/queues.py", line 355, in get
#     with self._rlock:
#   File "/home/awa5114/.pyenv/versions/3.8.6/lib/python3.8/multiprocessing/queues.py", line 355, in get
#     with self._rlock:
#   File "/home/awa5114/.pyenv/versions/3.8.6/lib/python3.8/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
# KeyboardInterrupt
# KeyboardInterrupt
# KeyboardInterrupt
# KeyboardInterrupt
#   File "/home/awa5114/.pyenv/versions/3.8.6/lib/python3.8/multiprocessing/queues.py", line 355, in get
#     with self._rlock:
#   File "/home/awa5114/.pyenv/versions/3.8.6/lib/python3.8/multiprocessing/queues.py", line 355, in get
#     with self._rlock:
#   File "/home/awa5114/.pyenv/versions/3.8.6/lib/python3.8/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
# KeyboardInterrupt
#   File "/home/awa5114/.pyenv/versions/3.8.6/lib/python3.8/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#   File "/home/awa5114/.pyenv/versions/3.8.6/lib/python3.8/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
# KeyboardInterrupt
#   File "/home/awa5114/.pyenv/versions/3.8.6/lib/python3.8/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#   File "/home/awa5114/.pyenv/versions/3.8.6/lib/python3.8/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
# KeyboardInterrupt
# KeyboardInterrupt
# KeyboardInterrupt
# KeyboardInterrupt
# KeyboardInterrupt
#   File "/home/awa5114/.pyenv/versions/3.8.6/lib/python3.8/multiprocessing/connection.py", line 216, in recv_bytes
#     buf = self._recv_bytes(maxlength)
#   File "/home/awa5114/.pyenv/versions/3.8.6/lib/python3.8/multiprocessing/queues.py", line 355, in get
#     with self._rlock:
#   File "/home/awa5114/.pyenv/versions/3.8.6/lib/python3.8/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#   File "/home/awa5114/.pyenv/versions/3.8.6/lib/python3.8/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
# KeyboardInterrupt
#   File "/home/awa5114/.pyenv/versions/3.8.6/lib/python3.8/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#   File "/home/awa5114/.pyenv/versions/3.8.6/lib/python3.8/multiprocessing/queues.py", line 355, in get
#     with self._rlock:
# KeyboardInterrupt
#   File "/home/awa5114/.pyenv/versions/3.8.6/lib/python3.8/multiprocessing/connection.py", line 216, in recv_bytes
#     buf = self._recv_bytes(maxlength)
#   File "/home/awa5114/.pyenv/versions/3.8.6/lib/python3.8/multiprocessing/connection.py", line 216, in recv_bytes
#     buf = self._recv_bytes(maxlength)
# KeyboardInterrupt
#   File "/home/awa5114/.pyenv/versions/3.8.6/lib/python3.8/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
# KeyboardInterrupt
# KeyboardInterrupt
#   File "/home/awa5114/.pyenv/versions/3.8.6/lib/python3.8/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
# KeyboardInterrupt
# KeyboardInterrupt
#   File "/home/awa5114/.pyenv/versions/3.8.6/lib/python3.8/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
# KeyboardInterrupt
#   File "/home/awa5114/.pyenv/versions/3.8.6/lib/python3.8/multiprocessing/connection.py", line 414, in _recv_bytes
#     buf = self._recv(4)
# KeyboardInterrupt
#   File "/home/awa5114/.pyenv/versions/3.8.6/lib/python3.8/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#   File "/home/awa5114/.pyenv/versions/3.8.6/lib/python3.8/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#   File "/home/awa5114/.pyenv/versions/3.8.6/lib/python3.8/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
# KeyboardInterrupt
#   File "/home/awa5114/.pyenv/versions/3.8.6/lib/python3.8/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#   File "/home/awa5114/.pyenv/versions/3.8.6/lib/python3.8/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
# KeyboardInterrupt
# KeyboardInterrupt
#   File "/home/awa5114/.pyenv/versions/3.8.6/lib/python3.8/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
# KeyboardInterrupt
# KeyboardInterrupt
#   File "/home/awa5114/.pyenv/versions/3.8.6/lib/python3.8/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
# KeyboardInterrupt
#   File "/home/awa5114/.pyenv/versions/3.8.6/lib/python3.8/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#   File "/home/awa5114/.pyenv/versions/3.8.6/lib/python3.8/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
# KeyboardInterrupt
# KeyboardInterrupt
# KeyboardInterrupt
# KeyboardInterrupt
#   File "/home/awa5114/.pyenv/versions/3.8.6/lib/python3.8/multiprocessing/connection.py", line 414, in _recv_bytes
#     buf = self._recv(4)
# KeyboardInterrupt
# KeyboardInterrupt
#   File "/home/awa5114/.pyenv/versions/3.8.6/lib/python3.8/multiprocessing/connection.py", line 414, in _recv_bytes
#     buf = self._recv(4)
# KeyboardInterrupt
# KeyboardInterrupt
# KeyboardInterrupt
#   File "/home/awa5114/.pyenv/versions/3.8.6/lib/python3.8/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
# KeyboardInterrupt
# KeyboardInterrupt
#   File "/home/awa5114/.pyenv/versions/3.8.6/lib/python3.8/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
# KeyboardInterrupt
# KeyboardInterrupt
# KeyboardInterrupt
# KeyboardInterrupt
# KeyboardInterrupt
# KeyboardInterrupt
# KeyboardInterrupt
# KeyboardInterrupt
#   File "/home/awa5114/.pyenv/versions/3.8.6/lib/python3.8/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#   File "/home/awa5114/.pyenv/versions/3.8.6/lib/python3.8/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
# KeyboardInterrupt
#   File "/home/awa5114/.pyenv/versions/3.8.6/lib/python3.8/multiprocessing/connection.py", line 379, in _recv
#     chunk = read(handle, remaining)
# KeyboardInterrupt
#   File "/home/awa5114/.pyenv/versions/3.8.6/lib/python3.8/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
# KeyboardInterrupt
# KeyboardInterrupt
# KeyboardInterrupt
# KeyboardInterrupt
# KeyboardInterrupt
#   File "/home/awa5114/.pyenv/versions/3.8.6/lib/python3.8/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#   File "/home/awa5114/.pyenv/versions/3.8.6/lib/python3.8/multiprocessing/connection.py", line 414, in _recv_bytes
#     buf = self._recv(4)
# KeyboardInterrupt
# KeyboardInterrupt
# KeyboardInterrupt
# KeyboardInterrupt
# KeyboardInterrupt
# KeyboardInterrupt
# KeyboardInterrupt
# KeyboardInterrupt
# KeyboardInterrupt
#   File "/home/awa5114/.pyenv/versions/3.8.6/lib/python3.8/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
# KeyboardInterrupt
# KeyboardInterrupt
#   File "/home/awa5114/.pyenv/versions/3.8.6/lib/python3.8/multiprocessing/connection.py", line 379, in _recv
#     chunk = read(handle, remaining)
# KeyboardInterrupt
#   File "/home/awa5114/.pyenv/versions/3.8.6/lib/python3.8/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#   File "/home/awa5114/.pyenv/versions/3.8.6/lib/python3.8/multiprocessing/connection.py", line 414, in _recv_bytes
#     buf = self._recv(4)
# KeyboardInterrupt
#   File "/home/awa5114/.pyenv/versions/3.8.6/lib/python3.8/multiprocessing/connection.py", line 379, in _recv
#     chunk = read(handle, remaining)
# KeyboardInterrupt
#   File "/home/awa5114/.pyenv/versions/3.8.6/lib/python3.8/multiprocessing/connection.py", line 379, in _recv
#     chunk = read(handle, remaining)
# KeyboardInterrupt
# KeyboardInterrupt
# KeyboardInterrupt
# KeyboardInterrupt
# KeyboardInterrupt
#   File "/home/awa5114/.pyenv/versions/3.8.6/lib/python3.8/multiprocessing/connection.py", line 379, in _recv
#     chunk = read(handle, remaining)
# KeyboardInterrupt
# KeyboardInterrupt
# KeyboardInterrupt
# KeyboardInterrupt
# KeyboardInterrupt
# KeyboardInterrupt

# %%
filepaths
