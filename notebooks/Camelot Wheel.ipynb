# %%
import pandas as pd
camelot_wheel = pd.DataFrame()

# %%
camelot_wheel["cw_number"] = ""
camelot_wheel["key"] = ""
camelot_wheel["neighbor_top"] = ""
camelot_wheel["neighbor_left"] = ""
camelot_wheel["neighbor_right"] = ""

# %%
'C Maj', 'C# Maj', 'D Maj', 'D# Maj', 'E Maj', 'F Maj', 'F# Maj', 'G Maj', 'G# Maj', 'A Maj', 'A# Maj', 'B Maj',
'c min', 'c# min', 'd min', 'd# min', 'e min', 'f min', 'f# min', 'g min', 'g# min', 'a min', 'a# min', 'b min'
# Out:
# ('c min',
#  'c# min',
#  'd min',
#  'd# min',
#  'e min',
#  'f min',
#  'f# min',
#  'g min',
#  'g# min',
#  'a min',
#  'a# min',
#  'b min')

# %% [markdown]
# Lower energy / deeper sound => moving 1 number down
#
# higher energy => moving 1 number up

# %%
A1='g# min'
A2='d# min'
A3='a# min'
A4='f min'
A5='c min'
A6='g min'
A7='d min'
A8='a min'
A9='e min'
A10='b min'
A11='f# min'
A12='c# min'
B1='B Maj'
B2='F# Maj'
B3='C# Maj'
B4='G# Maj'
B5='D# Maj'
B6='A# Maj'
B7='F Maj'
B8='C Maj'
B9='G Maj'
B10='D Maj'
B11='A Maj'
B12='E Maj'

# %%
A1_dict = {"cw_number": "1A", "key":A1, "neighbor_top":B1, "neighbor_left":A12, "neighbor_right":A2}
A2_dict = {"cw_number": "1A", "key":A2, "neighbor_top":B2, "neighbor_left":A1, "neighbor_right":A3}
A3_dict = {"cw_number": "1A", "key":A3, "neighbor_top":B3, "neighbor_left":A2, "neighbor_right":A4}
A4_dict = {"cw_number": "1A", "key":A4, "neighbor_top":B4, "neighbor_left":A3, "neighbor_right":A5}
A5_dict = {"cw_number": "1A", "key":A5, "neighbor_top":B5, "neighbor_left":A4, "neighbor_right":A6}
A6_dict = {"cw_number": "1A", "key":A6, "neighbor_top":B6, "neighbor_left":A5, "neighbor_right":A7}
A7_dict = {"cw_number": "1A", "key":A7, "neighbor_top":B7, "neighbor_left":A6, "neighbor_right":A8}
A8_dict = {"cw_number": "1A", "key":A8, "neighbor_top":B8, "neighbor_left":A7, "neighbor_right":A9}
A9_dict = {"cw_number": "1A", "key":A9, "neighbor_top":B9, "neighbor_left":A8, "neighbor_right":A10}
A10_dict = {"cw_number": "1A", "key":A10, "neighbor_top":B10, "neighbor_left":A9, "neighbor_right":A11}
A11_dict = {"cw_number": "1A", "key":A11, "neighbor_top":B11, "neighbor_left":A10, "neighbor_right":A12}
A12_dict = {"cw_number": "1A", "key":A12, "neighbor_top":B12, "neighbor_left":A11, "neighbor_right":A1}

B1_dict = {"cw_number": "1A", "key":B1, "neighbor_top":A1, "neighbor_left":B12, "neighbor_right":B2}
B2_dict = {"cw_number": "1A", "key":B2, "neighbor_top":A2, "neighbor_left":B1, "neighbor_right":B3}
B3_dict = {"cw_number": "1A", "key":B3, "neighbor_top":A3, "neighbor_left":B2, "neighbor_right":B4}
B4_dict = {"cw_number": "1A", "key":B4, "neighbor_top":A4, "neighbor_left":B3, "neighbor_right":B5}
B5_dict = {"cw_number": "1A", "key":B5, "neighbor_top":A5, "neighbor_left":B4, "neighbor_right":B6}
B6_dict = {"cw_number": "1A", "key":B6, "neighbor_top":A6, "neighbor_left":B5, "neighbor_right":B7}
B7_dict = {"cw_number": "1A", "key":B7, "neighbor_top":A7, "neighbor_left":B6, "neighbor_right":B8}
B8_dict = {"cw_number": "1A", "key":B8, "neighbor_top":A8, "neighbor_left":B7, "neighbor_right":B9}
B9_dict = {"cw_number": "1A", "key":B9, "neighbor_top":A9, "neighbor_left":B8, "neighbor_right":B10}
B10_dict = {"cw_number": "1A", "key":B10, "neighbor_top":A10, "neighbor_left":B9, "neighbor_right":B11}
B11_dict = {"cw_number": "1A", "key":B11, "neighbor_top":A11, "neighbor_left":B10, "neighbor_right":B12}
B12_dict = {"cw_number": "1A", "key":B12, "neighbor_top":A12, "neighbor_left":B11, "neighbor_right":B1}

dicts = [A1_dict, A2_dict, A3_dict, A4_dict, A5_dict, A6_dict, A7_dict, A8_dict, A9_dict, A10_dict, A11_dict, A12_dict, 
         B1_dict, B2_dict, B3_dict, B4_dict, B5_dict, B6_dict, B7_dict, B8_dict, B9_dict, B10_dict, B11_dict, B12_dict]

# %%
camelot_wheel.append(dicts, ignore_index=True)
# Out:
#    cw_number     key neighbor_top neighbor_left neighbor_right
# 0         1A  g# min        B Maj        c# min         d# min
# 1         1A  d# min       F# Maj        g# min         a# min
# 2         1A  a# min       C# Maj        d# min          f min
# 3         1A   f min       G# Maj        a# min          c min
# 4         1A   c min       D# Maj         f min          g min
# 5         1A   g min       A# Maj         c min          d min
# 6         1A   d min        F Maj         g min          a min
# 7         1A   a min        C Maj         d min          e min
# 8         1A   e min        G Maj         a min          b min
# 9         1A   b min        D Maj         e min         f# min
# 10        1A  f# min        A Maj         b min         c# min
# 11        1A  c# min        E Maj        f# min         g# min
# 12        1A   B Maj       g# min         E Maj         F# Maj
# 13        1A  F# Maj       d# min         B Maj         C# Maj
# ...

# %%
A2 = {"cw_number": "2A",
 "key":'d# min',
 "neighbor_top":'F# Maj',
 "neighbor_left":'g# min',
 "neighbor_right":'a# min'}

A3 = {"cw_number": "3A",
 "key":'a# min',
 "neighbor_top":'C# Maj',
 "neighbor_left":'d# min',
 "neighbor_right":'f min'}

A4 = {"cw_number": "4A",
 "key":'f min',
 "neighbor_top":,
 "neighbor_left":'a# min',
 "neighbor_right":}

A5 = {"cw_number": "5A",
 "key":'c min',
 "neighbor_top":'D# Maj',
 "neighbor_left":,
 "neighbor_right":}

A6 = {"cw_number": "6A",
 "key":,
 "neighbor_top":,
 "neighbor_left":,
 "neighbor_right":}

A7 = {"cw_number": "7A",
 "key":,
 "neighbor_top":,
 "neighbor_left":,
 "neighbor_right":}

A8 = {"cw_number": "8A",
 "key":,
 "neighbor_top":,
 "neighbor_left":,
 "neighbor_right":}

A9 = {"cw_number": "9A",
 "key":,
 "neighbor_top":,
 "neighbor_left":,
 "neighbor_right":}

A10 = {"cw_number": "10A",
 "key":,
 "neighbor_top":,
 "neighbor_left":,
 "neighbor_right":}

A11 = {"cw_number": "11A",
 "key":,
 "neighbor_top":,
 "neighbor_left":,
 "neighbor_right":}

A12 = {"cw_number": "12A",
 "key":,
 "neighbor_top":,
 "neighbor_left":,
 "neighbor_right":}
